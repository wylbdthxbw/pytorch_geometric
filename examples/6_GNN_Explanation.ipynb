# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install -q captum

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# 2.0.1

# %% [markdown]
# # Explaining GNN Model Predictions using Captum
#
# In this tutorial we demonstrate how to apply feature attribution methods to graphs. Specifically, we try to find the most important edges for each instance prediction.
#
# We use the Mutagenicity dataset from [TUDatasets](https://chrsmrrs.github.io/datasets/). This dataset consists of 4337 molecule graphs where the task is to predict the molecule mutagenicity.

# %% [markdown]
# ## Loading the dataset
#
# We load the dataset and use 10% of the data as the test split.

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import TUDataset

path = '.'
dataset = TUDataset(path, name='Mutagenicity').shuffle()
test_dataset = dataset[:len(dataset) // 10]
train_dataset = dataset[len(dataset) // 10:]
test_loader = DataLoader(test_dataset, batch_size=128)
train_loader = DataLoader(train_dataset, batch_size=128)
# Out:
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/Mutagenicity.zip
# Extracting .\Mutagenicity\Mutagenicity.zip
# Processing...
# Done!

# %% [markdown]
# ## Visualizing the data
#
# We define some utility functions for visualizing the molecules and draw a random molecule.

# %%
import networkx as nx
import numpy as np

from torch_geometric.utils import to_networkx


def draw_molecule(g, edge_mask=None, draw_edge_labels=False):
    g = g.copy().to_undirected()
    node_labels = {}
    for u, data in g.nodes(data=True):
        node_labels[u] = data['name']
    pos = nx.planar_layout(g)
    pos = nx.spring_layout(g, pos=pos)
    if edge_mask is None:
        edge_color = 'black'
        widths = None
    else:
        edge_color = [edge_mask[(u, v)] for u, v in g.edges()]
        widths = [x * 10 for x in edge_color]
    nx.draw(g, pos=pos, labels=node_labels, width=widths,
            edge_color=edge_color, edge_cmap=plt.cm.Blues,
            node_color='azure')

    if draw_edge_labels and edge_mask is not None:
        edge_labels = {k: ('%.2f' % v) for k, v in edge_mask.items()}
        nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels,
                                    font_color='red')
    plt.show()


def to_molecule(data):
    ATOM_MAP = ['C', 'O', 'Cl', 'H', 'N', 'F',
                'Br', 'S', 'P', 'I', 'Na', 'K', 'Li', 'Ca']
    g = to_networkx(data, node_attrs=['x'])
    for u, data in g.nodes(data=True):
        data['name'] = ATOM_MAP[data['x'].index(1.0)]
        del data['x']
    return g

# %% [markdown]
# ## Sample visualization
#
# We sample a single molecule from train_dataset and visualize it

# %%
import random

data = random.choice([t for t in train_dataset])
mol = to_molecule(data)
plt.figure(figsize=(10, 5))
draw_molecule(mol)

# %% [markdown]
# ## Training the model
#
# In the next section, we train a GNN model with 5 convolution layers. We use GraphConv which supports `edge_weight` as a parameter. Many convolution layers in Pytorch Geometric supoort this argument.

# %% [markdown]
# ### Define the model

# %%
import torch
from torch.nn import Linear
import torch.nn.functional as F

from torch_geometric.nn import GraphConv, global_add_pool

class Net(torch.nn.Module):
    def __init__(self, dim):
        super(Net, self).__init__()

        num_features = dataset.num_features
        self.dim = dim

        self.conv1 = GraphConv(num_features, dim)
        self.conv2 = GraphConv(dim, dim)
        self.conv3 = GraphConv(dim, dim)
        self.conv4 = GraphConv(dim, dim)
        self.conv5 = GraphConv(dim, dim)

        self.lin1 = Linear(dim, dim)
        self.lin2 = Linear(dim, dataset.num_classes)

    def forward(self, x, edge_index, batch, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight).relu()
        x = self.conv2(x, edge_index, edge_weight).relu()
        x = self.conv3(x, edge_index, edge_weight).relu()
        x = self.conv4(x, edge_index, edge_weight).relu()
        x = self.conv5(x, edge_index, edge_weight).relu()
        x = global_add_pool(x, batch)
        x = self.lin1(x).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)

# %% [markdown]
# ### Define train and test functions

# %%
def train(epoch):
    model.train()

    if epoch == 51:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.5 * param_group['lr']

    loss_all = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.edge_index, data.batch)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_dataset)


def tst(loader):
    model.eval()

    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.edge_index, data.batch)
        pred = output.max(dim=1)[1]
        correct += pred.eq(data.y).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ### Train the model for 100 epochs
#
# The accuracy should be around 80% in the end

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(dim=32).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(1, 101):
    loss = train(epoch)
    train_acc = tst(train_loader)
    test_acc = tst(test_loader)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, '
          f'Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 0.8664, Train Acc: 0.6519, Test Acc: 0.6651
# Epoch: 002, Loss: 0.6415, Train Acc: 0.6942, Test Acc: 0.6998
# Epoch: 003, Loss: 0.6014, Train Acc: 0.7029, Test Acc: 0.7113
# Epoch: 004, Loss: 0.5812, Train Acc: 0.7198, Test Acc: 0.7344
# Epoch: 005, Loss: 0.5644, Train Acc: 0.7341, Test Acc: 0.7413
# Epoch: 006, Loss: 0.5500, Train Acc: 0.7551, Test Acc: 0.7667
# Epoch: 007, Loss: 0.5390, Train Acc: 0.7748, Test Acc: 0.7829
# Epoch: 008, Loss: 0.5192, Train Acc: 0.7823, Test Acc: 0.7875
# Epoch: 009, Loss: 0.5135, Train Acc: 0.7851, Test Acc: 0.7806
# Epoch: 010, Loss: 0.5066, Train Acc: 0.7925, Test Acc: 0.7968
# Epoch: 011, Loss: 0.4926, Train Acc: 0.7948, Test Acc: 0.7968
# Epoch: 012, Loss: 0.4800, Train Acc: 0.8087, Test Acc: 0.7945
# Epoch: 013, Loss: 0.4808, Train Acc: 0.8120, Test Acc: 0.7991
# Epoch: 014, Loss: 0.4686, Train Acc: 0.8199, Test Acc: 0.8129
# Epoch: 015, Loss: 0.4670, Train Acc: 0.8174, Test Acc: 0.8106
# Epoch: 016, Loss: 0.4587, Train Acc: 0.8163, Test Acc: 0.8083
# Epoch: 017, Loss: 0.4529, Train Acc: 0.8204, Test Acc: 0.8129
# Epoch: 018, Loss: 0.4404, Train Acc: 0.8279, Test Acc: 0.8152
# Epoch: 019, Loss: 0.4319, Train Acc: 0.8256, Test Acc: 0.8245
# Epoch: 020, Loss: 0.4249, Train Acc: 0.8343, Test Acc: 0.8291
# Epoch: 021, Loss: 0.4235, Train Acc: 0.8394, Test Acc: 0.8314
# Epoch: 022, Loss: 0.4216, Train Acc: 0.8338, Test Acc: 0.8360
# Epoch: 023, Loss: 0.4188, Train Acc: 0.8332, Test Acc: 0.8245
# Epoch: 024, Loss: 0.4071, Train Acc: 0.8432, Test Acc: 0.8360
# Epoch: 025, Loss: 0.4107, Train Acc: 0.8299, Test Acc: 0.8129
# Epoch: 026, Loss: 0.4046, Train Acc: 0.8404, Test Acc: 0.8291
# Epoch: 027, Loss: 0.4053, Train Acc: 0.8373, Test Acc: 0.8291
# Epoch: 028, Loss: 0.3988, Train Acc: 0.8368, Test Acc: 0.8314
# Epoch: 029, Loss: 0.4015, Train Acc: 0.8376, Test Acc: 0.8222
# Epoch: 030, Loss: 0.3890, Train Acc: 0.8422, Test Acc: 0.8360
# Epoch: 031, Loss: 0.3907, Train Acc: 0.8499, Test Acc: 0.8476
# Epoch: 032, Loss: 0.3957, Train Acc: 0.8371, Test Acc: 0.8199
# Epoch: 033, Loss: 0.3817, Train Acc: 0.8461, Test Acc: 0.8291
# Epoch: 034, Loss: 0.3847, Train Acc: 0.8502, Test Acc: 0.8430
# Epoch: 035, Loss: 0.3937, Train Acc: 0.8519, Test Acc: 0.8406
# Epoch: 036, Loss: 0.3772, Train Acc: 0.8589, Test Acc: 0.8522
# Epoch: 037, Loss: 0.3795, Train Acc: 0.8543, Test Acc: 0.8337
# Epoch: 038, Loss: 0.3931, Train Acc: 0.8548, Test Acc: 0.8430
# Epoch: 039, Loss: 0.3743, Train Acc: 0.8571, Test Acc: 0.8222
# Epoch: 040, Loss: 0.3701, Train Acc: 0.8589, Test Acc: 0.8291
# Epoch: 041, Loss: 0.3767, Train Acc: 0.8502, Test Acc: 0.8199
# Epoch: 042, Loss: 0.3601, Train Acc: 0.8624, Test Acc: 0.8406
# Epoch: 043, Loss: 0.3691, Train Acc: 0.8560, Test Acc: 0.8360
# Epoch: 044, Loss: 0.3603, Train Acc: 0.8612, Test Acc: 0.8314
# Epoch: 045, Loss: 0.3600, Train Acc: 0.8522, Test Acc: 0.8430
# Epoch: 046, Loss: 0.3579, Train Acc: 0.8619, Test Acc: 0.8337
# Epoch: 047, Loss: 0.3513, Train Acc: 0.8683, Test Acc: 0.8430
# Epoch: 048, Loss: 0.3564, Train Acc: 0.8645, Test Acc: 0.8383
# Epoch: 049, Loss: 0.3422, Train Acc: 0.8289, Test Acc: 0.8083
# Epoch: 050, Loss: 0.3539, Train Acc: 0.8589, Test Acc: 0.8430
# Epoch: 051, Loss: 0.3537, Train Acc: 0.8591, Test Acc: 0.8314
# Epoch: 052, Loss: 0.3300, Train Acc: 0.8701, Test Acc: 0.8453
# Epoch: 053, Loss: 0.3423, Train Acc: 0.8691, Test Acc: 0.8430
# Epoch: 054, Loss: 0.3292, Train Acc: 0.8686, Test Acc: 0.8499
# Epoch: 055, Loss: 0.3317, Train Acc: 0.8686, Test Acc: 0.8406
# Epoch: 056, Loss: 0.3203, Train Acc: 0.8719, Test Acc: 0.8522
# Epoch: 057, Loss: 0.3269, Train Acc: 0.8686, Test Acc: 0.8383
# Epoch: 058, Loss: 0.3189, Train Acc: 0.8758, Test Acc: 0.8406
# Epoch: 059, Loss: 0.3219, Train Acc: 0.8722, Test Acc: 0.8406
# Epoch: 060, Loss: 0.3247, Train Acc: 0.8676, Test Acc: 0.8383
# Epoch: 061, Loss: 0.3127, Train Acc: 0.8730, Test Acc: 0.8522
# Epoch: 062, Loss: 0.3111, Train Acc: 0.8758, Test Acc: 0.8453
# Epoch: 063, Loss: 0.3139, Train Acc: 0.8745, Test Acc: 0.8476
# Epoch: 064, Loss: 0.3074, Train Acc: 0.8755, Test Acc: 0.8453
# Epoch: 065, Loss: 0.3021, Train Acc: 0.8760, Test Acc: 0.8476
# Epoch: 066, Loss: 0.3110, Train Acc: 0.8745, Test Acc: 0.8522
# Epoch: 067, Loss: 0.3096, Train Acc: 0.8786, Test Acc: 0.8545
# Epoch: 068, Loss: 0.2971, Train Acc: 0.8773, Test Acc: 0.8545
# Epoch: 069, Loss: 0.3019, Train Acc: 0.8796, Test Acc: 0.8568
# Epoch: 070, Loss: 0.2915, Train Acc: 0.8796, Test Acc: 0.8499
# Epoch: 071, Loss: 0.2942, Train Acc: 0.8750, Test Acc: 0.8545
# Epoch: 072, Loss: 0.3015, Train Acc: 0.8817, Test Acc: 0.8591
# Epoch: 073, Loss: 0.3016, Train Acc: 0.8794, Test Acc: 0.8406
# Epoch: 074, Loss: 0.2851, Train Acc: 0.8811, Test Acc: 0.8545
# Epoch: 075, Loss: 0.2932, Train Acc: 0.8770, Test Acc: 0.8383
# Epoch: 076, Loss: 0.2948, Train Acc: 0.8814, Test Acc: 0.8476
# Epoch: 077, Loss: 0.2978, Train Acc: 0.8768, Test Acc: 0.8453
# Epoch: 078, Loss: 0.2832, Train Acc: 0.8755, Test Acc: 0.8545
# Epoch: 079, Loss: 0.2796, Train Acc: 0.8845, Test Acc: 0.8430
# Epoch: 080, Loss: 0.2850, Train Acc: 0.8788, Test Acc: 0.8522
# Epoch: 081, Loss: 0.2820, Train Acc: 0.8888, Test Acc: 0.8591
# Epoch: 082, Loss: 0.2925, Train Acc: 0.8845, Test Acc: 0.8637
# Epoch: 083, Loss: 0.2887, Train Acc: 0.8791, Test Acc: 0.8568
# Epoch: 084, Loss: 0.2963, Train Acc: 0.8832, Test Acc: 0.8661
# Epoch: 085, Loss: 0.2892, Train Acc: 0.8870, Test Acc: 0.8568
# Epoch: 086, Loss: 0.2831, Train Acc: 0.8840, Test Acc: 0.8453
# Epoch: 087, Loss: 0.3098, Train Acc: 0.8596, Test Acc: 0.8245
# Epoch: 088, Loss: 0.3070, Train Acc: 0.8612, Test Acc: 0.8268
# Epoch: 089, Loss: 0.2899, Train Acc: 0.8763, Test Acc: 0.8453
# Epoch: 090, Loss: 0.2770, Train Acc: 0.8712, Test Acc: 0.8314
# Epoch: 091, Loss: 0.2839, Train Acc: 0.8794, Test Acc: 0.8453
# Epoch: 092, Loss: 0.2782, Train Acc: 0.8678, Test Acc: 0.8360
# Epoch: 093, Loss: 0.2712, Train Acc: 0.8832, Test Acc: 0.8406
# Epoch: 094, Loss: 0.2633, Train Acc: 0.8883, Test Acc: 0.8568
# Epoch: 095, Loss: 0.2618, Train Acc: 0.8888, Test Acc: 0.8545
# Epoch: 096, Loss: 0.2718, Train Acc: 0.8845, Test Acc: 0.8383
# Epoch: 097, Loss: 0.2732, Train Acc: 0.8852, Test Acc: 0.8406
# Epoch: 098, Loss: 0.2700, Train Acc: 0.8852, Test Acc: 0.8522
# Epoch: 099, Loss: 0.2591, Train Acc: 0.8868, Test Acc: 0.8499
# Epoch: 100, Loss: 0.2588, Train Acc: 0.8883, Test Acc: 0.8406

# %% [markdown]
# ## Explaining the predictions
#
# Now we look at two popular attribution methods. First, we calculate the gradient of the output with respect to the edge weights $w_{e_i}$. Edge weights are initially one for all edges.
# For the saliency method, we use the absolute value of the gradient as the attribution value for each edge:
#
# $$
# Attribution_{e_i} = |\frac{\partial F(x)}{\partial w_{e_i}}|
# $$
#
# Where $x$ is the input and $F(x)$ is the output of the GNN model on input $x$.
#
# For Integrated Gradients method, we interpolate between the current input and a baseline input where the weight of all edges is zero and accumulate the gradient values for each edge:
#
# $$
# Attribution_{e_i} = \int_{\alpha =0}^1 \frac{\partial F(x_{\alpha)}}{\partial w_{e_i}} d\alpha
# $$
#
# Where $x_{\alpha}$ is the same as the original input graph but the weight of all edges is set to $\alpha$. Integrated Gradients complete formulation is more complicated but since our initial edge weights are equal to one and the baseline is zero, it can be simplified to the formulation above. You can read more about this method [here](https://arxiv.org/abs/1703.01365). Of course, this can not be calculated directly and is approximated by a discrete sum.
#
# We use the [captum](https://captum.ai/) library for calculating the attribution values. We define the `model_forward` function which calculates the `batch` argument assuming that we are only explaining a single graph at a time.

# %%
from captum.attr import Saliency, IntegratedGradients

def model_forward(edge_mask, data):
    batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
    out = model(data.x, data.edge_index, batch, edge_mask)
    return out


def explain(method, data, target=0):
    input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
    if method == 'ig':
        ig = IntegratedGradients(model_forward)
        mask = ig.attribute(input_mask, target=target,
                            additional_forward_args=(data,),
                            internal_batch_size=data.edge_index.shape[1])
    elif method == 'saliency':
        saliency = Saliency(model_forward)
        mask = saliency.attribute(input_mask, target=target,
                                  additional_forward_args=(data,))
    else:
        raise Exception('Unknown explanation method')

    edge_mask = np.abs(mask.cpu().detach().numpy())
    if edge_mask.max() > 0:  # avoid division by zero
        edge_mask = edge_mask / edge_mask.max()
    return edge_mask

# %% [markdown]
# Finally we take a random sample from the test dataset and run the explanation methods. For a simpler visualization, we make the graph undirected and merge the explanations of each edge in both directions.
#
# It is known that NO2 substructure makes the molecules mutagenic in many cases and you can verify this by the model explanations.
#
# Mutagenic molecules have label 0 in this dataset and we only sample from those molecules but you can change the code and see the explanations for the other class as well.
#
# In this visualization, edge colors and thickness represent the importance. You can also see the numeric value by passing `draw_edge_labels` to `draw_molecule` function.
#
# As you can see Integrated Gradients tend to create more accurate explanations.

# %%
import random
from collections import defaultdict

def aggregate_edge_directions(edge_mask, data):
    edge_mask_dict = defaultdict(float)
    for val, u, v in list(zip(edge_mask, *data.edge_index)):
        u, v = u.item(), v.item()
        if u > v:
            u, v = v, u
        edge_mask_dict[(u, v)] += val
    return edge_mask_dict


data = random.choice([t for t in test_dataset if not t.y.item()])
mol = to_molecule(data)

for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
    edge_mask = explain(method, data, target=0)
    edge_mask_dict = aggregate_edge_directions(edge_mask, data)
    plt.figure(figsize=(10, 5))
    plt.title(title)
    draw_molecule(mol, edge_mask_dict)
